# %% [markdown]
# # TM-Score Comparison Between PDB Folders
#
# This notebook compares structures between two folders:
# - **Generated PDBs folder**: Contains predicted/generated structures
# - **Original PDBs folder**: Contains reference/original structures
#
# It calculates TM-scores and saves results to CSV.

# %%
import subprocess
import os
import pandas as pd
import re
import glob
from datetime import datetime

print("TM-Score Comparison Tool Loaded")
print(f"Timestamp: {datetime.now()}")
# Out:
# TM-Score Comparison Tool Loaded
# Timestamp: 2025-09-05 04:23:33.255582

# %%
# Configuration - Update these paths for your setup
GENERATED_PDB_FOLDER = "PMPNN_Results"  # Folder with 505 generated PDBs
ORIGINAL_PDB_FOLDER = "original_pdbs"    # Folder with 505 original PDBs
OUTPUT_CSV = "PMPNN_TMscore.csv"      # Output CSV file name
TMSCORE_EXECUTABLE = "./TMscore"         # Path to TMscore executable

print(f"Generated PDB folder: {GENERATED_PDB_FOLDER}")
print(f"Original PDB folder: {ORIGINAL_PDB_FOLDER}")
print(f"Output CSV: {OUTPUT_CSV}")
print(f"TMscore executable: {TMSCORE_EXECUTABLE}")
# Out:
# Generated PDB folder: PMPNN_Results
# Original PDB folder: original_pdbs
# Output CSV: PMPNN_TMscore.csv
# TMscore executable: ./TMscore

# %%
def run_tm_score_folder_comparison(generated_folder, original_folder, output_csv):
    """
    Compare all PDB files between two folders using TM-score
    
    Args:
        generated_folder: Path to folder containing generated/predicted PDBs
        original_folder: Path to folder containing original/reference PDBs
        output_csv: Path to output CSV file
    
    Returns:
        DataFrame with comparison results
    """
    
    # Check if folders exist
    if not os.path.exists(generated_folder):
        print(f"Error: Generated PDB folder not found: {generated_folder}")
        return None
    
    if not os.path.exists(original_folder):
        print(f"Error: Original PDB folder not found: {original_folder}")
        return None
    
    # Get all PDB files from generated folder
    generated_pdbs = glob.glob(os.path.join(generated_folder, "*.pdb"))
    generated_pdbs.sort()
    
    print(f"Found {len(generated_pdbs)} PDB files in generated folder")
    
    if len(generated_pdbs) == 0:
        print("No PDB files found in generated folder!")
        return None
    
    # Show first few filenames for debugging
    print(f"\nFirst 5 generated PDB files:")
    for i, pdb in enumerate(generated_pdbs[:5]):
        base_name = os.path.splitext(os.path.basename(pdb))[0]
        print(f"  {i+1}. {os.path.basename(pdb)} -> looking for: {base_name}_peptide.pdb")
    
    # Check what's actually in the original folder
    original_pdbs = glob.glob(os.path.join(original_folder, "*.pdb"))
    original_pdbs.sort()
    print(f"\nFound {len(original_pdbs)} PDB files in original folder")
    print(f"First 5 original PDB files:")
    for i, pdb in enumerate(original_pdbs[:5]):
        print(f"  {i+1}. {os.path.basename(pdb)}")
    
    print(f"\nExpected mapping pattern: generated_name.pdb -> generated_name_peptide.pdb")
    print("If this doesn't look right, we need to adjust the mapping logic.\n")
    
    # Store all results
    all_results = []
    successful_comparisons = 0
    failed_comparisons = 0
    
    print("\nStarting TM-score comparisons...")
    print("=" * 50)
    
    for i, generated_pdb in enumerate(generated_pdbs):
        # Extract base name for matching
        base_name = os.path.splitext(os.path.basename(generated_pdb))[0]
        
        # Look for corresponding original PDB with _peptide suffix
        original_pdb = os.path.join(original_folder, f"{base_name}_peptide.pdb")
        
        print(f"\nProcessing {i+1}/{len(generated_pdbs)}: {base_name}")
        print(f"  Generated: {generated_pdb}")
        print(f"  Looking for: {original_pdb}")
        
        if not os.path.exists(original_pdb):
            print(f"  ⚠️  Original PDB not found: {original_pdb}")
            failed_comparisons += 1
            
            # Store failed result
            result = {
                'pdb_id': base_name,
                'tm_score': None,
                'original_pdb_path': original_pdb,
                'status': 'original_not_found'
            }
            all_results.append(result)
            continue
        
        try:
            # Set up environment for TMscore
            env = os.environ.copy()
            env["LD_LIBRARY_PATH"] = "/home/ribodiffusion/.conda/envs/ribodiffusionenv/lib:" + env.get("LD_LIBRARY_PATH", "")
            
            # Run TM-score comparison
            command = subprocess.run(
                [TMSCORE_EXECUTABLE, generated_pdb, original_pdb],
                capture_output=True,
                text=True,
                timeout=120,  # 2 minute timeout
                env=env
            )
            
            if command.returncode == 0:
                # Parse TM-score output - try multiple patterns
                output = command.stdout
                
                # Print output for debugging (first few cases)
                if i < 3:  # Only for first 3 files
                    print(f"  Debug - TMscore output preview:")
                    print(f"    {output[:200]}...")
                
                # Check if TMscore found no common residues
                if "no common residues" in output.lower():
                    print(f"  ⚠️  No common residues found between structures")
                    failed_comparisons += 1
                    tm_score = None
                    status = 'no_common_residues'
                else:
                    # Try different TM-score patterns
                    tm_score = None
                    
                    # Pattern 1: Standard format
                    tm_score_match = re.search(r"TM-score\s*=\s*([\d.]+)", output, re.IGNORECASE)
                    if tm_score_match:
                        tm_score = float(tm_score_match.group(1))
                    else:
                        # Pattern 2: Alternative formats
                        patterns = [
                            r"TM-score\s*:\s*([\d.]+)",
                            r"TM\s*=\s*([\d.]+)",
                            r"TM-score\s+([\d.]+)",
                            r"TM\s*score\s*=\s*([\d.]+)",
                            r"([\d.]+)\s*\(normalized by length",  # Sometimes TM-score appears before this text
                        ]
                        
                        for pattern in patterns:
                            match = re.search(pattern, output, re.IGNORECASE)
                            if match:
                                tm_score = float(match.group(1))
                                break
                    
                    if tm_score is not None:
                        print(f"  ✅ TM-score: {tm_score:.4f}")
                        successful_comparisons += 1
                        status = 'success'
                    else:
                        print(f"  ❌ Could not parse TM-score from output")
                        # Show debug info for parsing failures to understand the format
                        # Show first 10 parsing failures for debugging
                        if failed_comparisons < 10:
                            print(f"    DEBUG - Full TMscore output for {base_name}:")
                            print(f"    {output}")
                            print(f"    END DEBUG OUTPUT")
                        failed_comparisons += 1
                        status = 'parse_failed'
                
                # Store result (only the columns you need)
                result = {
                    'pdb_id': base_name,
                    'tm_score': tm_score,
                    'original_pdb_path': original_pdb,
                    'status': status
                }
                
            else:
                print(f"  ❌ TMscore command failed (return code: {command.returncode})")
                print(f"     Error: {command.stderr[:200]}...")
                failed_comparisons += 1
                
                result = {
                    'pdb_id': base_name,
                    'tm_score': None,
                    'original_pdb_path': original_pdb,
                    'status': 'tmscore_failed'
                }
                
        except subprocess.TimeoutExpired:
            print(f"  ⏱️  TMscore command timed out")
            failed_comparisons += 1
            
            result = {
                'pdb_id': base_name,
                'tm_score': None,
                'original_pdb_path': original_pdb,
                'status': 'timeout'
            }
            
        except Exception as e:
            print(f"  💥 Error: {str(e)}")
            failed_comparisons += 1
            
            result = {
                'pdb_id': base_name,
                'tm_score': None,
                'original_pdb_path': original_pdb,
                'status': f'error: {str(e)[:50]}'
            }
        
        all_results.append(result)
    
    # Create results DataFrame
    if all_results:
        results_df = pd.DataFrame(all_results)
        
        # Sort by TM-score (descending, with NaN values last)
        results_df = results_df.sort_values('tm_score', ascending=False, na_position='last')
        
        # Save to CSV
        results_df.to_csv(output_csv, index=False)
        
        print(f"\n{'='*50}")
        print(f"COMPARISON COMPLETE!")
        print(f"{'='*50}")
        print(f"Total comparisons: {len(all_results)}")
        print(f"Successful: {successful_comparisons}")
        print(f"Failed: {failed_comparisons}")
        print(f"Success rate: {(successful_comparisons/len(all_results))*100:.1f}%")
        
        # Calculate statistics for successful comparisons
        successful_results = results_df[results_df['status'] == 'success']
        if len(successful_results) > 0:
            print(f"\nTM-Score Statistics:")
            print(f"Average: {successful_results['tm_score'].mean():.4f}")
            print(f"Median: {successful_results['tm_score'].median():.4f}")
            print(f"Best: {successful_results['tm_score'].max():.4f}")
            print(f"Worst: {successful_results['tm_score'].min():.4f}")
            print(f"Std Dev: {successful_results['tm_score'].std():.4f}")
        
        print(f"\n📄 Results saved to: {output_csv}")
        
        return results_df
    else:
        print("No results to save")
        return None

# %%
# Run the comparison
print("Starting TM-score comparison between folders...")
print(f"Make sure {TMSCORE_EXECUTABLE} is available and has execute permissions")
print("Use: chmod +x TMscore")
print()

results = run_tm_score_folder_comparison(
    GENERATED_PDB_FOLDER, 
    ORIGINAL_PDB_FOLDER, 
    OUTPUT_CSV
)
# Out:
# Starting TM-score comparison between folders...
# Make sure ./TMscore is available and has execute permissions
# Use: chmod +x TMscore
#
# Found 505 PDB files in generated folder
#
# First 5 generated PDB files:
#   1. 1a1r_C.pdb -> looking for: 1a1r_C_peptide.pdb
#   2. 1a1u_A.pdb -> looking for: 1a1u_A_peptide.pdb
#   3. 1a2c_L.pdb -> looking for: 1a2c_L_peptide.pdb
#   4. 1a2x_B.pdb -> looking for: 1a2x_B_peptide.pdb
#   5. 1a38_P.pdb -> looking for: 1a38_P_peptide.pdb
#
# Found 505 PDB files in original folder
# First 5 original PDB files:
#   1. 1a1r_C_peptide.pdb
#   2. 1a1u_A_peptide.pdb
#   3. 1a2c_L_peptide.pdb
#   4. 1a2x_B_peptide.pdb
#   5. 1a38_P_peptide.pdb
#
# Expected mapping pattern: generated_name.pdb -> generated_name_peptide.pdb
# If this doesn't look right, we need to adjust the mapping logic.
#
#
# Starting TM-score comparisons...
# ==================================================
#
# Processing 1/505: 1a1r_C
#   Generated: PMPNN_Results/1a1r_C.pdb
#   Looking for: original_pdbs/1a1r_C_peptide.pdb
#   Debug - TMscore output preview:
#      There is no common residues in the input structures
# ...
#   ⚠️  No common residues found between structures
#
# Processing 2/505: 1a1u_A
#   Generated: PMPNN_Results/1a1u_A.pdb
#   Looking for: original_pdbs/1a1u_A_peptide.pdb
#   Debug - TMscore output preview:
#
#  *****************************************************************************
#  *                                 TM-SCORE                                  *
#  * A scoring function to assess the simil...
#   ✅ TM-score: 0.0495
#
# Processing 3/505: 1a2c_L
#   Generated: PMPNN_Results/1a2c_L.pdb
#   Looking for: original_pdbs/1a2c_L_peptide.pdb
#   Debug - TMscore output preview:
#
#  *****************************************************************************
#  *                                 TM-SCORE                                  *
#  * A scoring function to assess the simil...
#   ✅ TM-score: 0.1689
#
# Processing 4/505: 1a2x_B
#   Generated: PMPNN_Results/1a2x_B.pdb
#   Looking for: original_pdbs/1a2x_B_peptide.pdb
#   ✅ TM-score: 0.8160
#
# Processing 5/505: 1a38_P
#   Generated: PMPNN_Results/1a38_P.pdb
#   Looking for: original_pdbs/1a38_P_peptide.pdb
#   ✅ TM-score: 0.2491
#
# Processing 6/505: 1a3b_L
#   Generated: PMPNN_Results/1a3b_L.pdb
#   Looking for: original_pdbs/1a3b_L_peptide.pdb
#   ✅ TM-score: 0.2073
#
# Processing 7/505: 1a3e_L
#   Generated: PMPNN_Results/1a3e_L.pdb
#   Looking for: original_pdbs/1a3e_L_peptide.pdb
#   ✅ TM-score: 0.2119
#
# Processing 8/505: 1a46_L
#   Generated: PMPNN_Results/1a46_L.pdb
#   Looking for: original_pdbs/1a46_L_peptide.pdb
#   ✅ TM-score: 0.1990
#
# Processing 9/505: 1a4w_L
#   Generated: PMPNN_Results/1a4w_L.pdb
#   Looking for: original_pdbs/1a4w_L_peptide.pdb
#   ✅ TM-score: 0.1732
#
# Processing 10/505: 1a5g_L
#   Generated: PMPNN_Results/1a5g_L.pdb
#   Looking for: original_pdbs/1a5g_L_peptide.pdb
#   ✅ TM-score: 0.1682
#
# Processing 11/505: 1a61_L
#   Generated: PMPNN_Results/1a61_L.pdb
#   Looking for: original_pdbs/1a61_L_peptide.pdb
#   ✅ TM-score: 0.1383
#
# Processing 12/505: 1a7f_A
#   Generated: PMPNN_Results/1a7f_A.pdb
#   Looking for: original_pdbs/1a7f_A_peptide.pdb
#   ✅ TM-score: 0.2289
#
# Processing 13/505: 1a7f_B
#   Generated: PMPNN_Results/1a7f_B.pdb
#   Looking for: original_pdbs/1a7f_B_peptide.pdb
#   ✅ TM-score: 0.3797
#
# Processing 14/505: 1a93_A
#   Generated: PMPNN_Results/1a93_A.pdb
#   Looking for: original_pdbs/1a93_A_peptide.pdb
#   ✅ TM-score: 0.3914
#
# Processing 15/505: 1abi_I
#   Generated: PMPNN_Results/1abi_I.pdb
#   Looking for: original_pdbs/1abi_I_peptide.pdb
#   ✅ TM-score: 0.0940
#
# Processing 16/505: 1abi_L
#   Generated: PMPNN_Results/1abi_L.pdb
#   Looking for: original_pdbs/1abi_L_peptide.pdb
#   ✅ TM-score: 0.1753
#
# Processing 17/505: 1abj_L
#   Generated: PMPNN_Results/1abj_L.pdb
#   Looking for: original_pdbs/1abj_L_peptide.pdb
#   ✅ TM-score: 0.1532
#
# Processing 18/505: 1acy_P
#   Generated: PMPNN_Results/1acy_P.pdb
#   Looking for: original_pdbs/1acy_P_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 19/505: 1ad8_L
#   Generated: PMPNN_Results/1ad8_L.pdb
#   Looking for: original_pdbs/1ad8_L_peptide.pdb
#   ✅ TM-score: 0.2124
#
# Processing 20/505: 1ae8_L
#   Generated: PMPNN_Results/1ae8_L.pdb
#   Looking for: original_pdbs/1ae8_L_peptide.pdb
#   ✅ TM-score: 0.1911
#
# Processing 21/505: 1afe_L
#   Generated: PMPNN_Results/1afe_L.pdb
#   Looking for: original_pdbs/1afe_L_peptide.pdb
#   ✅ TM-score: 0.1320
#
# Processing 22/505: 1afo_A
#   Generated: PMPNN_Results/1afo_A.pdb
#   Looking for: original_pdbs/1afo_A_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 23/505: 1aht_L
#   Generated: PMPNN_Results/1aht_L.pdb
#   Looking for: original_pdbs/1aht_L_peptide.pdb
#   ✅ TM-score: 0.1970
#
# Processing 24/505: 1ai0_A
#   Generated: PMPNN_Results/1ai0_A.pdb
#   Looking for: original_pdbs/1ai0_A_peptide.pdb
#   ✅ TM-score: 0.3192
#
# Processing 25/505: 1ai0_B
#   Generated: PMPNN_Results/1ai0_B.pdb
#   Looking for: original_pdbs/1ai0_B_peptide.pdb
#   ✅ TM-score: 0.4616
#
# Processing 26/505: 1ai1_P
#   Generated: PMPNN_Results/1ai1_P.pdb
#   Looking for: original_pdbs/1ai1_P_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 27/505: 1ai8_L
#   Generated: PMPNN_Results/1ai8_L.pdb
#   Looking for: original_pdbs/1ai8_L_peptide.pdb
#   ✅ TM-score: 0.2083
#
# Processing 28/505: 1aik_C
#   Generated: PMPNN_Results/1aik_C.pdb
#   Looking for: original_pdbs/1aik_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 29/505: 1aik_N
#   Generated: PMPNN_Results/1aik_N.pdb
#   Looking for: original_pdbs/1aik_N_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 30/505: 1aix_L
#   Generated: PMPNN_Results/1aix_L.pdb
#   Looking for: original_pdbs/1aix_L_peptide.pdb
#   ✅ TM-score: 0.2053
#
# Processing 31/505: 1aiy_A
#   Generated: PMPNN_Results/1aiy_A.pdb
#   Looking for: original_pdbs/1aiy_A_peptide.pdb
#   ✅ TM-score: 0.3957
#
# Processing 32/505: 1aiy_B
#   Generated: PMPNN_Results/1aiy_B.pdb
#   Looking for: original_pdbs/1aiy_B_peptide.pdb
#   ✅ TM-score: 0.4486
#
# Processing 33/505: 1amt_A
#   Generated: PMPNN_Results/1amt_A.pdb
#   Looking for: original_pdbs/1amt_A_peptide.pdb
#   ✅ TM-score: 0.0821
#
# Processing 34/505: 1an1_I
#   Generated: PMPNN_Results/1an1_I.pdb
#   Looking for: original_pdbs/1an1_I_peptide.pdb
#   ✅ TM-score: 0.2400
#
# Processing 35/505: 1aph_A
#   Generated: PMPNN_Results/1aph_A.pdb
#   Looking for: original_pdbs/1aph_A_peptide.pdb
#   ✅ TM-score: 0.2708
#
# Processing 36/505: 1aph_B
#   Generated: PMPNN_Results/1aph_B.pdb
#   Looking for: original_pdbs/1aph_B_peptide.pdb
#   ✅ TM-score: 0.3926
#
# Processing 37/505: 1apm_I
#   Generated: PMPNN_Results/1apm_I.pdb
#   Looking for: original_pdbs/1apm_I_peptide.pdb
#   ✅ TM-score: 0.2041
#
# Processing 38/505: 1aq5_A
#   Generated: PMPNN_Results/1aq5_A.pdb
#   Looking for: original_pdbs/1aq5_A_peptide.pdb
#   ✅ TM-score: 0.4163
#
# Processing 39/505: 1as4_B
#   Generated: PMPNN_Results/1as4_B.pdb
#   Looking for: original_pdbs/1as4_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 40/505: 1atp_I
#   Generated: PMPNN_Results/1atp_I.pdb
#   Looking for: original_pdbs/1atp_I_peptide.pdb
#   ✅ TM-score: 0.2147
#
# Processing 41/505: 1avf_P
#   Generated: PMPNN_Results/1avf_P.pdb
#   Looking for: original_pdbs/1avf_P_peptide.pdb
#   ✅ TM-score: 0.4648
#
# Processing 42/505: 1avg_L
#   Generated: PMPNN_Results/1avg_L.pdb
#   Looking for: original_pdbs/1avg_L_peptide.pdb
#   ✅ TM-score: 0.1492
#
# Processing 43/505: 1aw8_A
#   Generated: PMPNN_Results/1aw8_A.pdb
#   Looking for: original_pdbs/1aw8_A_peptide.pdb
#   ✅ TM-score: 0.1768
#
# Processing 44/505: 1awf_L
#   Generated: PMPNN_Results/1awf_L.pdb
#   Looking for: original_pdbs/1awf_L_peptide.pdb
#   ✅ TM-score: 0.2089
#
# Processing 45/505: 1awh_A
#   Generated: PMPNN_Results/1awh_A.pdb
#   Looking for: original_pdbs/1awh_A_peptide.pdb
#   ✅ TM-score: 0.1553
#
# Processing 46/505: 1axc_B
#   Generated: PMPNN_Results/1axc_B.pdb
#   Looking for: original_pdbs/1axc_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 47/505: 1ay6_L
#   Generated: PMPNN_Results/1ay6_L.pdb
#   Looking for: original_pdbs/1ay6_L_peptide.pdb
#   ✅ TM-score: 0.1593
#
# Processing 48/505: 1b17_A
#   Generated: PMPNN_Results/1b17_A.pdb
#   Looking for: original_pdbs/1b17_A_peptide.pdb
#   ✅ TM-score: 0.2312
#
# Processing 49/505: 1b17_B
#   Generated: PMPNN_Results/1b17_B.pdb
#   Looking for: original_pdbs/1b17_B_peptide.pdb
#   ✅ TM-score: 0.4473
#
# Processing 50/505: 1b18_A
#   Generated: PMPNN_Results/1b18_A.pdb
#   Looking for: original_pdbs/1b18_A_peptide.pdb
#   ✅ TM-score: 0.2057
#
# Processing 51/505: 1b18_B
#   Generated: PMPNN_Results/1b18_B.pdb
#   Looking for: original_pdbs/1b18_B_peptide.pdb
#   ✅ TM-score: 0.4468
#
# Processing 52/505: 1b19_A
#   Generated: PMPNN_Results/1b19_A.pdb
#   Looking for: original_pdbs/1b19_A_peptide.pdb
#   ✅ TM-score: 0.2113
#
# Processing 53/505: 1b19_B
#   Generated: PMPNN_Results/1b19_B.pdb
#   Looking for: original_pdbs/1b19_B_peptide.pdb
#   ✅ TM-score: 0.4245
#
# Processing 54/505: 1b2a_A
#   Generated: PMPNN_Results/1b2a_A.pdb
#   Looking for: original_pdbs/1b2a_A_peptide.pdb
#   ✅ TM-score: 0.2230
#
# Processing 55/505: 1b2a_B
#   Generated: PMPNN_Results/1b2a_B.pdb
#   Looking for: original_pdbs/1b2a_B_peptide.pdb
#   ✅ TM-score: 0.4451
#
# Processing 56/505: 1b2b_A
#   Generated: PMPNN_Results/1b2b_A.pdb
#   Looking for: original_pdbs/1b2b_A_peptide.pdb
#   ✅ TM-score: 0.2875
#
# Processing 57/505: 1b2b_B
#   Generated: PMPNN_Results/1b2b_B.pdb
#   Looking for: original_pdbs/1b2b_B_peptide.pdb
#   ✅ TM-score: 0.5100
#
# Processing 58/505: 1b2c_A
#   Generated: PMPNN_Results/1b2c_A.pdb
#   Looking for: original_pdbs/1b2c_A_peptide.pdb
#   ✅ TM-score: 0.2394
#
# Processing 59/505: 1b2c_B
#   Generated: PMPNN_Results/1b2c_B.pdb
#   Looking for: original_pdbs/1b2c_B_peptide.pdb
#   ✅ TM-score: 0.4210
#
# Processing 60/505: 1b2d_A
#   Generated: PMPNN_Results/1b2d_A.pdb
#   Looking for: original_pdbs/1b2d_A_peptide.pdb
#   ✅ TM-score: 0.2317
#
# Processing 61/505: 1b2d_B
#   Generated: PMPNN_Results/1b2d_B.pdb
#   Looking for: original_pdbs/1b2d_B_peptide.pdb
#   ✅ TM-score: 0.5460
#
# Processing 62/505: 1b2e_A
#   Generated: PMPNN_Results/1b2e_A.pdb
#   Looking for: original_pdbs/1b2e_A_peptide.pdb
#   ✅ TM-score: 0.2885
#
# Processing 63/505: 1b2e_B
#   Generated: PMPNN_Results/1b2e_B.pdb
#   Looking for: original_pdbs/1b2e_B_peptide.pdb
#   ✅ TM-score: 0.4660
#
# Processing 64/505: 1b2f_A
#   Generated: PMPNN_Results/1b2f_A.pdb
#   Looking for: original_pdbs/1b2f_A_peptide.pdb
#   ✅ TM-score: 0.3685
#
# Processing 65/505: 1b2f_B
#   Generated: PMPNN_Results/1b2f_B.pdb
#   Looking for: original_pdbs/1b2f_B_peptide.pdb
#   ✅ TM-score: 0.5417
#
# Processing 66/505: 1b2g_A
#   Generated: PMPNN_Results/1b2g_A.pdb
#   Looking for: original_pdbs/1b2g_A_peptide.pdb
#   ✅ TM-score: 0.2828
#
# Processing 67/505: 1b2g_B
#   Generated: PMPNN_Results/1b2g_B.pdb
#   Looking for: original_pdbs/1b2g_B_peptide.pdb
#   ✅ TM-score: 0.4934
#
# Processing 68/505: 1b5g_L
#   Generated: PMPNN_Results/1b5g_L.pdb
#   Looking for: original_pdbs/1b5g_L_peptide.pdb
#   ✅ TM-score: 0.2009
#
# Processing 69/505: 1b7x_A
#   Generated: PMPNN_Results/1b7x_A.pdb
#   Looking for: original_pdbs/1b7x_A_peptide.pdb
#   ✅ TM-score: 0.2015
#
# Processing 70/505: 1b9e_A
#   Generated: PMPNN_Results/1b9e_A.pdb
#   Looking for: original_pdbs/1b9e_A_peptide.pdb
#   ✅ TM-score: 0.3145
#
# Processing 71/505: 1b9e_B
#   Generated: PMPNN_Results/1b9e_B.pdb
#   Looking for: original_pdbs/1b9e_B_peptide.pdb
#   ✅ TM-score: 0.5108
#
# Processing 72/505: 1ba8_A
#   Generated: PMPNN_Results/1ba8_A.pdb
#   Looking for: original_pdbs/1ba8_A_peptide.pdb
#   ✅ TM-score: 0.1951
#
# Processing 73/505: 1bb0_A
#   Generated: PMPNN_Results/1bb0_A.pdb
#   Looking for: original_pdbs/1bb0_A_peptide.pdb
#   ✅ TM-score: 0.1482
#
# Processing 74/505: 1bb1_A
#   Generated: PMPNN_Results/1bb1_A.pdb
#   Looking for: original_pdbs/1bb1_A_peptide.pdb
#   ✅ TM-score: 0.4882
#
# Processing 75/505: 1bbr_L
#   Generated: PMPNN_Results/1bbr_L.pdb
#   Looking for: original_pdbs/1bbr_L_peptide.pdb
#   ✅ TM-score: 0.1690
#
# Processing 76/505: 1bcu_L
#   Generated: PMPNN_Results/1bcu_L.pdb
#   Looking for: original_pdbs/1bcu_L_peptide.pdb
#   ✅ TM-score: 0.1674
#
# Processing 77/505: 1ben_A
#   Generated: PMPNN_Results/1ben_A.pdb
#   Looking for: original_pdbs/1ben_A_peptide.pdb
#   ✅ TM-score: 0.3783
#
# Processing 78/505: 1ben_B
#   Generated: PMPNN_Results/1ben_B.pdb
#   Looking for: original_pdbs/1ben_B_peptide.pdb
#   ✅ TM-score: 0.5045
#
# Processing 79/505: 1bh8_A
#   Generated: PMPNN_Results/1bh8_A.pdb
#   Looking for: original_pdbs/1bh8_A_peptide.pdb
#   ✅ TM-score: 0.2711
#
# Processing 80/505: 1bh9_A
#   Generated: PMPNN_Results/1bh9_A.pdb
#   Looking for: original_pdbs/1bh9_A_peptide.pdb
#   ✅ TM-score: 0.2852
#
# Processing 81/505: 1bhx_A
#   Generated: PMPNN_Results/1bhx_A.pdb
#   Looking for: original_pdbs/1bhx_A_peptide.pdb
#   ✅ TM-score: 0.1878
#
# Processing 82/505: 1bi6_H
#   Generated: PMPNN_Results/1bi6_H.pdb
#   Looking for: original_pdbs/1bi6_H_peptide.pdb
#   ✅ TM-score: 0.5042
#
# Processing 83/505: 1bkv_A
#   Generated: PMPNN_Results/1bkv_A.pdb
#   Looking for: original_pdbs/1bkv_A_peptide.pdb
#   ✅ TM-score: 0.3189
#
# Processing 84/505: 1bmm_L
#   Generated: PMPNN_Results/1bmm_L.pdb
#   Looking for: original_pdbs/1bmm_L_peptide.pdb
#   ✅ TM-score: 0.2035
#
# Processing 85/505: 1bmn_L
#   Generated: PMPNN_Results/1bmn_L.pdb
#   Looking for: original_pdbs/1bmn_L_peptide.pdb
#   ✅ TM-score: 0.1754
#
# Processing 86/505: 1bom_A
#   Generated: PMPNN_Results/1bom_A.pdb
#   Looking for: original_pdbs/1bom_A_peptide.pdb
#   ✅ TM-score: 0.2641
#
# Processing 87/505: 1bom_B
#   Generated: PMPNN_Results/1bom_B.pdb
#   Looking for: original_pdbs/1bom_B_peptide.pdb
#   ✅ TM-score: 0.4663
#
# Processing 88/505: 1bon_A
#   Generated: PMPNN_Results/1bon_A.pdb
#   Looking for: original_pdbs/1bon_A_peptide.pdb
#   ✅ TM-score: 0.2295
#
# Processing 89/505: 1bon_B
#   Generated: PMPNN_Results/1bon_B.pdb
#   Looking for: original_pdbs/1bon_B_peptide.pdb
#   ✅ TM-score: 0.4530
#
# Processing 90/505: 1bph_A
#   Generated: PMPNN_Results/1bph_A.pdb
#   Looking for: original_pdbs/1bph_A_peptide.pdb
#   ✅ TM-score: 0.2693
#
# Processing 91/505: 1bph_B
#   Generated: PMPNN_Results/1bph_B.pdb
#   Looking for: original_pdbs/1bph_B_peptide.pdb
#   ✅ TM-score: 0.4210
#
# Processing 92/505: 1bqp_B
#   Generated: PMPNN_Results/1bqp_B.pdb
#   Looking for: original_pdbs/1bqp_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 93/505: 1bth_L
#   Generated: PMPNN_Results/1bth_L.pdb
#   Looking for: original_pdbs/1bth_L_peptide.pdb
#   ✅ TM-score: 0.1750
#
# Processing 94/505: 1bzv_A
#   Generated: PMPNN_Results/1bzv_A.pdb
#   Looking for: original_pdbs/1bzv_A_peptide.pdb
#   ✅ TM-score: 0.2612
#
# Processing 95/505: 1bzv_B
#   Generated: PMPNN_Results/1bzv_B.pdb
#   Looking for: original_pdbs/1bzv_B_peptide.pdb
#   ✅ TM-score: 0.4540
#
# Processing 96/505: 1c1u_L
#   Generated: PMPNN_Results/1c1u_L.pdb
#   Looking for: original_pdbs/1c1u_L_peptide.pdb
#   ✅ TM-score: 0.1879
#
# Processing 97/505: 1c1v_L
#   Generated: PMPNN_Results/1c1v_L.pdb
#   Looking for: original_pdbs/1c1v_L_peptide.pdb
#   ✅ TM-score: 0.2007
#
# Processing 98/505: 1c1w_L
#   Generated: PMPNN_Results/1c1w_L.pdb
#   Looking for: original_pdbs/1c1w_L_peptide.pdb
#   ✅ TM-score: 0.1969
#
# Processing 99/505: 1c5l_L
#   Generated: PMPNN_Results/1c5l_L.pdb
#   Looking for: original_pdbs/1c5l_L_peptide.pdb
#   ✅ TM-score: 0.1334
#
# Processing 100/505: 1c5n_L
#   Generated: PMPNN_Results/1c5n_L.pdb
#   Looking for: original_pdbs/1c5n_L_peptide.pdb
#   ✅ TM-score: 0.2027
#
# Processing 101/505: 1c5o_L
#   Generated: PMPNN_Results/1c5o_L.pdb
#   Looking for: original_pdbs/1c5o_L_peptide.pdb
#   ✅ TM-score: 0.1445
#
# Processing 102/505: 1c5w_A
#   Generated: PMPNN_Results/1c5w_A.pdb
#   Looking for: original_pdbs/1c5w_A_peptide.pdb
#   ✅ TM-score: 0.1111
#
# Processing 103/505: 1c5x_A
#   Generated: PMPNN_Results/1c5x_A.pdb
#   Looking for: original_pdbs/1c5x_A_peptide.pdb
#   ✅ TM-score: 0.1111
#
# Processing 104/505: 1c5y_A
#   Generated: PMPNN_Results/1c5y_A.pdb
#   Looking for: original_pdbs/1c5y_A_peptide.pdb
#   ✅ TM-score: 0.1111
#
# Processing 105/505: 1c5z_A
#   Generated: PMPNN_Results/1c5z_A.pdb
#   Looking for: original_pdbs/1c5z_A_peptide.pdb
#   ✅ TM-score: 0.1111
#
# Processing 106/505: 1c8o_B
#   Generated: PMPNN_Results/1c8o_B.pdb
#   Looking for: original_pdbs/1c8o_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 107/505: 1c94_A
#   Generated: PMPNN_Results/1c94_A.pdb
#   Looking for: original_pdbs/1c94_A_peptide.pdb
#   ✅ TM-score: 0.4480
#
# Processing 108/505: 1ca8_A
#   Generated: PMPNN_Results/1ca8_A.pdb
#   Looking for: original_pdbs/1ca8_A_peptide.pdb
#   ✅ TM-score: 0.1783
#
# Processing 109/505: 1cag_A
#   Generated: PMPNN_Results/1cag_A.pdb
#   Looking for: original_pdbs/1cag_A_peptide.pdb
#   ✅ TM-score: 0.2026
#
# Processing 110/505: 1cdk_I
#   Generated: PMPNN_Results/1cdk_I.pdb
#   Looking for: original_pdbs/1cdk_I_peptide.pdb
#   ✅ TM-score: 0.3885
#
# Processing 111/505: 1cdl_E
#   Generated: PMPNN_Results/1cdl_E.pdb
#   Looking for: original_pdbs/1cdl_E_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 112/505: 1cdm_B
#   Generated: PMPNN_Results/1cdm_B.pdb
#   Looking for: original_pdbs/1cdm_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 113/505: 1ce0_A
#   Generated: PMPNN_Results/1ce0_A.pdb
#   Looking for: original_pdbs/1ce0_A_peptide.pdb
#   ✅ TM-score: 0.3716
#
# Processing 114/505: 1ce9_A
#   Generated: PMPNN_Results/1ce9_A.pdb
#   Looking for: original_pdbs/1ce9_A_peptide.pdb
#   ✅ TM-score: 0.8204
#
# Processing 115/505: 1cf4_B
#   Generated: PMPNN_Results/1cf4_B.pdb
#   Looking for: original_pdbs/1cf4_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 116/505: 1cff_B
#   Generated: PMPNN_Results/1cff_B.pdb
#   Looking for: original_pdbs/1cff_B_peptide.pdb
#   ✅ TM-score: 0.3287
#
# Processing 117/505: 1cfw_A
#   Generated: PMPNN_Results/1cfw_A.pdb
#   Looking for: original_pdbs/1cfw_A_peptide.pdb
#   ✅ TM-score: 0.9064
#
# Processing 118/505: 1cgd_A
#   Generated: PMPNN_Results/1cgd_A.pdb
#   Looking for: original_pdbs/1cgd_A_peptide.pdb
#   ✅ TM-score: 0.1858
#
# Processing 119/505: 1ciq_A
#   Generated: PMPNN_Results/1ciq_A.pdb
#   Looking for: original_pdbs/1ciq_A_peptide.pdb
#   ✅ TM-score: 0.3246
#
# Processing 120/505: 1ciq_B
#   Generated: PMPNN_Results/1ciq_B.pdb
#   Looking for: original_pdbs/1ciq_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 121/505: 1cir_A
#   Generated: PMPNN_Results/1cir_A.pdb
#   Looking for: original_pdbs/1cir_A_peptide.pdb
#   ✅ TM-score: 0.3646
#
# Processing 122/505: 1cir_B
#   Generated: PMPNN_Results/1cir_B.pdb
#   Looking for: original_pdbs/1cir_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 123/505: 1ckk_B
#   Generated: PMPNN_Results/1ckk_B.pdb
#   Looking for: original_pdbs/1ckk_B_peptide.pdb
#   ✅ TM-score: 0.4598
#
# Processing 124/505: 1clv_I
#   Generated: PMPNN_Results/1clv_I.pdb
#   Looking for: original_pdbs/1clv_I_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 125/505: 1cm1_B
#   Generated: PMPNN_Results/1cm1_B.pdb
#   Looking for: original_pdbs/1cm1_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 126/505: 1cm4_B
#   Generated: PMPNN_Results/1cm4_B.pdb
#   Looking for: original_pdbs/1cm4_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 127/505: 1cmk_I
#   Generated: PMPNN_Results/1cmk_I.pdb
#   Looking for: original_pdbs/1cmk_I_peptide.pdb
#   ✅ TM-score: 0.3027
#
# Processing 128/505: 1cn3_F
#   Generated: PMPNN_Results/1cn3_F.pdb
#   Looking for: original_pdbs/1cn3_F_peptide.pdb
#   ✅ TM-score: 0.4239
#
# Processing 129/505: 1cos_A
#   Generated: PMPNN_Results/1cos_A.pdb
#   Looking for: original_pdbs/1cos_A_peptide.pdb
#   ✅ TM-score: 0.8308
#
# Processing 130/505: 1cph_A
#   Generated: PMPNN_Results/1cph_A.pdb
#   Looking for: original_pdbs/1cph_A_peptide.pdb
#   ✅ TM-score: 0.3246
#
# Processing 131/505: 1cph_B
#   Generated: PMPNN_Results/1cph_B.pdb
#   Looking for: original_pdbs/1cph_B_peptide.pdb
#   ✅ TM-score: 0.5113
#
# Processing 132/505: 1cq4_A
#   Generated: PMPNN_Results/1cq4_A.pdb
#   Looking for: original_pdbs/1cq4_A_peptide.pdb
#   ✅ TM-score: 0.1124
#
# Processing 133/505: 1cq4_B
#   Generated: PMPNN_Results/1cq4_B.pdb
#   Looking for: original_pdbs/1cq4_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 134/505: 1csb_A
#   Generated: PMPNN_Results/1csb_A.pdb
#   Looking for: original_pdbs/1csb_A_peptide.pdb
#   ✅ TM-score: 0.6424
#
# Processing 135/505: 1cta_A
#   Generated: PMPNN_Results/1cta_A.pdb
#   Looking for: original_pdbs/1cta_A_peptide.pdb
#   ✅ TM-score: 0.6244
#
# Processing 136/505: 1ctd_A
#   Generated: PMPNN_Results/1ctd_A.pdb
#   Looking for: original_pdbs/1ctd_A_peptide.pdb
#   ✅ TM-score: 0.3861
#
# Processing 137/505: 1ctp_I
#   Generated: PMPNN_Results/1ctp_I.pdb
#   Looking for: original_pdbs/1ctp_I_peptide.pdb
#   ✅ TM-score: 0.1360
#
# Processing 138/505: 1czq_A
#   Generated: PMPNN_Results/1czq_A.pdb
#   Looking for: original_pdbs/1czq_A_peptide.pdb
#   ✅ TM-score: 0.4299
#
# Processing 139/505: 1d3d_A
#   Generated: PMPNN_Results/1d3d_A.pdb
#   Looking for: original_pdbs/1d3d_A_peptide.pdb
#   ✅ TM-score: 0.1767
#
# Processing 140/505: 1d3p_A
#   Generated: PMPNN_Results/1d3p_A.pdb
#   Looking for: original_pdbs/1d3p_A_peptide.pdb
#   ✅ TM-score: 0.1707
#
# Processing 141/505: 1d3q_A
#   Generated: PMPNN_Results/1d3q_A.pdb
#   Looking for: original_pdbs/1d3q_A_peptide.pdb
#   ✅ TM-score: 0.1814
#
# Processing 142/505: 1d3t_A
#   Generated: PMPNN_Results/1d3t_A.pdb
#   Looking for: original_pdbs/1d3t_A_peptide.pdb
#   ✅ TM-score: 0.1754
#
# Processing 143/505: 1d4p_A
#   Generated: PMPNN_Results/1d4p_A.pdb
#   Looking for: original_pdbs/1d4p_A_peptide.pdb
#   ✅ TM-score: 0.1870
#
# Processing 144/505: 1d5s_B
#   Generated: PMPNN_Results/1d5s_B.pdb
#   Looking for: original_pdbs/1d5s_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 145/505: 1d6g_A
#   Generated: PMPNN_Results/1d6g_A.pdb
#   Looking for: original_pdbs/1d6g_A_peptide.pdb
#   ✅ TM-score: 0.2234
#
# Processing 146/505: 1dcd_A
#   Generated: PMPNN_Results/1dcd_A.pdb
#   Looking for: original_pdbs/1dcd_A_peptide.pdb
#   ✅ TM-score: 0.9505
#
# Processing 147/505: 1dd3_C
#   Generated: PMPNN_Results/1dd3_C.pdb
#   Looking for: original_pdbs/1dd3_C_peptide.pdb
#   ✅ TM-score: 0.8708
#
# Processing 148/505: 1dd4_C
#   Generated: PMPNN_Results/1dd4_C.pdb
#   Looking for: original_pdbs/1dd4_C_peptide.pdb
#   ✅ TM-score: 0.7971
#
# Processing 149/505: 1de7_L
#   Generated: PMPNN_Results/1de7_L.pdb
#   Looking for: original_pdbs/1de7_L_peptide.pdb
#   ✅ TM-score: 0.1399
#
# Processing 150/505: 1dei_A
#   Generated: PMPNN_Results/1dei_A.pdb
#   Looking for: original_pdbs/1dei_A_peptide.pdb
#   ✅ TM-score: 0.3747
#
# Processing 151/505: 1dei_B
#   Generated: PMPNN_Results/1dei_B.pdb
#   Looking for: original_pdbs/1dei_B_peptide.pdb
#   ✅ TM-score: 0.4441
#
# Processing 152/505: 1dev_B
#   Generated: PMPNN_Results/1dev_B.pdb
#   Looking for: original_pdbs/1dev_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 153/505: 1dfn_A
#   Generated: PMPNN_Results/1dfn_A.pdb
#   Looking for: original_pdbs/1dfn_A_peptide.pdb
#   ✅ TM-score: 0.1899
#
# Processing 154/505: 1dhg_A
#   Generated: PMPNN_Results/1dhg_A.pdb
#   Looking for: original_pdbs/1dhg_A_peptide.pdb
#   ✅ TM-score: 0.9305
#
# Processing 155/505: 1dit_L
#   Generated: PMPNN_Results/1dit_L.pdb
#   Looking for: original_pdbs/1dit_L_peptide.pdb
#   ✅ TM-score: 0.1766
#
# Processing 156/505: 1dit_P
#   Generated: PMPNN_Results/1dit_P.pdb
#   Looking for: original_pdbs/1dit_P_peptide.pdb
#   ✅ TM-score: 0.2307
#
# Processing 157/505: 1dm4_A
#   Generated: PMPNN_Results/1dm4_A.pdb
#   Looking for: original_pdbs/1dm4_A_peptide.pdb
#   ✅ TM-score: 0.1385
#
# Processing 158/505: 1dml_B
#   Generated: PMPNN_Results/1dml_B.pdb
#   Looking for: original_pdbs/1dml_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 159/505: 1dow_B
#   Generated: PMPNN_Results/1dow_B.pdb
#   Looking for: original_pdbs/1dow_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 160/505: 1dph_A
#   Generated: PMPNN_Results/1dph_A.pdb
#   Looking for: original_pdbs/1dph_A_peptide.pdb
#   ✅ TM-score: 0.3707
#
# Processing 161/505: 1dph_B
#   Generated: PMPNN_Results/1dph_B.pdb
#   Looking for: original_pdbs/1dph_B_peptide.pdb
#   ✅ TM-score: 0.5210
#
# Processing 162/505: 1dpj_B
#   Generated: PMPNN_Results/1dpj_B.pdb
#   Looking for: original_pdbs/1dpj_B_peptide.pdb
#   ✅ TM-score: 0.6220
#
# Processing 163/505: 1ds5_E
#   Generated: PMPNN_Results/1ds5_E.pdb
#   Looking for: original_pdbs/1ds5_E_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 164/505: 1dt7_X
#   Generated: PMPNN_Results/1dt7_X.pdb
#   Looking for: original_pdbs/1dt7_X_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 165/505: 1dum_A
#   Generated: PMPNN_Results/1dum_A.pdb
#   Looking for: original_pdbs/1dum_A_peptide.pdb
#   ✅ TM-score: 0.2886
#
# Processing 166/505: 1dva_X
#   Generated: PMPNN_Results/1dva_X.pdb
#   Looking for: original_pdbs/1dva_X_peptide.pdb
#   ✅ TM-score: 0.3339
#
# Processing 167/505: 1dwb_L
#   Generated: PMPNN_Results/1dwb_L.pdb
#   Looking for: original_pdbs/1dwb_L_peptide.pdb
#   ✅ TM-score: 0.2293
#
# Processing 168/505: 1dwc_L
#   Generated: PMPNN_Results/1dwc_L.pdb
#   Looking for: original_pdbs/1dwc_L_peptide.pdb
#   ✅ TM-score: 0.2044
#
# Processing 169/505: 1dwd_L
#   Generated: PMPNN_Results/1dwd_L.pdb
#   Looking for: original_pdbs/1dwd_L_peptide.pdb
#   ✅ TM-score: 0.1962
#
# Processing 170/505: 1dwe_L
#   Generated: PMPNN_Results/1dwe_L.pdb
#   Looking for: original_pdbs/1dwe_L_peptide.pdb
#   ✅ TM-score: 0.2545
#
# Processing 171/505: 1dx5_A
#   Generated: PMPNN_Results/1dx5_A.pdb
#   Looking for: original_pdbs/1dx5_A_peptide.pdb
#   ✅ TM-score: 0.1625
#
# Processing 172/505: 1dxg_A
#   Generated: PMPNN_Results/1dxg_A.pdb
#   Looking for: original_pdbs/1dxg_A_peptide.pdb
#   ✅ TM-score: 0.9475
#
# Processing 173/505: 1dzi_B
#   Generated: PMPNN_Results/1dzi_B.pdb
#   Looking for: original_pdbs/1dzi_B_peptide.pdb
#   ✅ TM-score: 0.3149
#
# Processing 174/505: 1e0a_B
#   Generated: PMPNN_Results/1e0a_B.pdb
#   Looking for: original_pdbs/1e0a_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 175/505: 1e0f_A
#   Generated: PMPNN_Results/1e0f_A.pdb
#   Looking for: original_pdbs/1e0f_A_peptide.pdb
#   ✅ TM-score: 0.1666
#
# Processing 176/505: 1eb1_L
#   Generated: PMPNN_Results/1eb1_L.pdb
#   Looking for: original_pdbs/1eb1_L_peptide.pdb
#   ✅ TM-score: 0.2076
#
# Processing 177/505: 1eba_C
#   Generated: PMPNN_Results/1eba_C.pdb
#   Looking for: original_pdbs/1eba_C_peptide.pdb
#   ✅ TM-score: 0.1904
#
# Processing 178/505: 1ebd_C
#   Generated: PMPNN_Results/1ebd_C.pdb
#   Looking for: original_pdbs/1ebd_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 179/505: 1ebp_C
#   Generated: PMPNN_Results/1ebp_C.pdb
#   Looking for: original_pdbs/1ebp_C_peptide.pdb
#   ✅ TM-score: 0.1750
#
# Processing 180/505: 1eci_A
#   Generated: PMPNN_Results/1eci_A.pdb
#   Looking for: original_pdbs/1eci_A_peptide.pdb
#   ✅ TM-score: 0.4504
#
# Processing 181/505: 1eci_B
#   Generated: PMPNN_Results/1eci_B.pdb
#   Looking for: original_pdbs/1eci_B_peptide.pdb
#   ✅ TM-score: 0.6146
#
# Processing 182/505: 1edm_B
#   Generated: PMPNN_Results/1edm_B.pdb
#   Looking for: original_pdbs/1edm_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 183/505: 1ees_B
#   Generated: PMPNN_Results/1ees_B.pdb
#   Looking for: original_pdbs/1ees_B_peptide.pdb
#   ✅ TM-score: 0.1685
#
# Processing 184/505: 1egp_A
#   Generated: PMPNN_Results/1egp_A.pdb
#   Looking for: original_pdbs/1egp_A_peptide.pdb
#   ✅ TM-score: 0.1792
#
# Processing 185/505: 1egp_B
#   Generated: PMPNN_Results/1egp_B.pdb
#   Looking for: original_pdbs/1egp_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 186/505: 1ehk_C
#   Generated: PMPNN_Results/1ehk_C.pdb
#   Looking for: original_pdbs/1ehk_C_peptide.pdb
#   ✅ TM-score: 0.4605
#
# Processing 187/505: 1ei8_A
#   Generated: PMPNN_Results/1ei8_A.pdb
#   Looking for: original_pdbs/1ei8_A_peptide.pdb
#   ✅ TM-score: 0.1707
#
# Processing 188/505: 1ejp_A
#   Generated: PMPNN_Results/1ejp_A.pdb
#   Looking for: original_pdbs/1ejp_A_peptide.pdb
#   ✅ TM-score: 0.1642
#
# Processing 189/505: 1ejq_A
#   Generated: PMPNN_Results/1ejq_A.pdb
#   Looking for: original_pdbs/1ejq_A_peptide.pdb
#   ✅ TM-score: 0.1090
#
# Processing 190/505: 1ept_A
#   Generated: PMPNN_Results/1ept_A.pdb
#   Looking for: original_pdbs/1ept_A_peptide.pdb
#   ✅ TM-score: 0.1241
#
# Processing 191/505: 1eq8_A
#   Generated: PMPNN_Results/1eq8_A.pdb
#   Looking for: original_pdbs/1eq8_A_peptide.pdb
#   ✅ TM-score: 0.5528
#
# Processing 192/505: 1et1_A
#   Generated: PMPNN_Results/1et1_A.pdb
#   Looking for: original_pdbs/1et1_A_peptide.pdb
#   ✅ TM-score: 0.4814
#
# Processing 193/505: 1etr_L
#   Generated: PMPNN_Results/1etr_L.pdb
#   Looking for: original_pdbs/1etr_L_peptide.pdb
#   ✅ TM-score: 0.1404
#
# Processing 194/505: 1ets_L
#   Generated: PMPNN_Results/1ets_L.pdb
#   Looking for: original_pdbs/1ets_L_peptide.pdb
#   ✅ TM-score: 0.1293
#
# Processing 195/505: 1ett_L
#   Generated: PMPNN_Results/1ett_L.pdb
#   Looking for: original_pdbs/1ett_L_peptide.pdb
#   ✅ TM-score: 0.1326
#
# Processing 196/505: 1ev3_A
#   Generated: PMPNN_Results/1ev3_A.pdb
#   Looking for: original_pdbs/1ev3_A_peptide.pdb
#   ✅ TM-score: 0.3021
#
# Processing 197/505: 1ev3_B
#   Generated: PMPNN_Results/1ev3_B.pdb
#   Looking for: original_pdbs/1ev3_B_peptide.pdb
#   ✅ TM-score: 0.5829
#
# Processing 198/505: 1ev6_A
#   Generated: PMPNN_Results/1ev6_A.pdb
#   Looking for: original_pdbs/1ev6_A_peptide.pdb
#   ✅ TM-score: 0.3277
#
# Processing 199/505: 1ev6_B
#   Generated: PMPNN_Results/1ev6_B.pdb
#   Looking for: original_pdbs/1ev6_B_peptide.pdb
#   ✅ TM-score: 0.5737
#
# Processing 200/505: 1evr_A
#   Generated: PMPNN_Results/1evr_A.pdb
#   Looking for: original_pdbs/1evr_A_peptide.pdb
#   ✅ TM-score: 0.3840
#
# Processing 201/505: 1evr_B
#   Generated: PMPNN_Results/1evr_B.pdb
#   Looking for: original_pdbs/1evr_B_peptide.pdb
#   ✅ TM-score: 0.5466
#
# Processing 202/505: 1ezx_B
#   Generated: PMPNN_Results/1ezx_B.pdb
#   Looking for: original_pdbs/1ezx_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 203/505: 1f0c_B
#   Generated: PMPNN_Results/1f0c_B.pdb
#   Looking for: original_pdbs/1f0c_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 204/505: 1f2s_I
#   Generated: PMPNN_Results/1f2s_I.pdb
#   Looking for: original_pdbs/1f2s_I_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 205/505: 1f58_P
#   Generated: PMPNN_Results/1f58_P.pdb
#   Looking for: original_pdbs/1f58_P_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 206/505: 1f93_E
#   Generated: PMPNN_Results/1f93_E.pdb
#   Looking for: original_pdbs/1f93_E_peptide.pdb
#   ✅ TM-score: 0.5897
#
# Processing 207/505: 1fav_C
#   Generated: PMPNN_Results/1fav_C.pdb
#   Looking for: original_pdbs/1fav_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 208/505: 1fbm_A
#   Generated: PMPNN_Results/1fbm_A.pdb
#   Looking for: original_pdbs/1fbm_A_peptide.pdb
#   ✅ TM-score: 0.3876
#
# Processing 209/505: 1fd3_A
#   Generated: PMPNN_Results/1fd3_A.pdb
#   Looking for: original_pdbs/1fd3_A_peptide.pdb
#   ✅ TM-score: 0.8866
#
# Processing 210/505: 1fd4_A
#   Generated: PMPNN_Results/1fd4_A.pdb
#   Looking for: original_pdbs/1fd4_A_peptide.pdb
#   ✅ TM-score: 0.9237
#
# Processing 211/505: 1fgl_B
#   Generated: PMPNN_Results/1fgl_B.pdb
#   Looking for: original_pdbs/1fgl_B_peptide.pdb
#   ✅ TM-score: 0.1074
#
# Processing 212/505: 1fiw_L
#   Generated: PMPNN_Results/1fiw_L.pdb
#   Looking for: original_pdbs/1fiw_L_peptide.pdb
#   ✅ TM-score: 0.1039
#
# Processing 213/505: 1fiz_L
#   Generated: PMPNN_Results/1fiz_L.pdb
#   Looking for: original_pdbs/1fiz_L_peptide.pdb
#   ✅ TM-score: 0.1524
#
# Processing 214/505: 1fll_X
#   Generated: PMPNN_Results/1fll_X.pdb
#   Looking for: original_pdbs/1fll_X_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 215/505: 1fm6_B
#   Generated: PMPNN_Results/1fm6_B.pdb
#   Looking for: original_pdbs/1fm6_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 216/505: 1fm9_B
#   Generated: PMPNN_Results/1fm9_B.pdb
#   Looking for: original_pdbs/1fm9_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 217/505: 1fmh_A
#   Generated: PMPNN_Results/1fmh_A.pdb
#   Looking for: original_pdbs/1fmh_A_peptide.pdb
#   ✅ TM-score: 0.6855
#
# Processing 218/505: 1fmo_I
#   Generated: PMPNN_Results/1fmo_I.pdb
#   Looking for: original_pdbs/1fmo_I_peptide.pdb
#   ✅ TM-score: 0.1845
#
# Processing 219/505: 1fpc_L
#   Generated: PMPNN_Results/1fpc_L.pdb
#   Looking for: original_pdbs/1fpc_L_peptide.pdb
#   ✅ TM-score: 0.2034
#
# Processing 220/505: 1fph_L
#   Generated: PMPNN_Results/1fph_L.pdb
#   Looking for: original_pdbs/1fph_L_peptide.pdb
#   ✅ TM-score: 0.1494
#
# Processing 221/505: 1fqj_C
#   Generated: PMPNN_Results/1fqj_C.pdb
#   Looking for: original_pdbs/1fqj_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 222/505: 1fu2_A
#   Generated: PMPNN_Results/1fu2_A.pdb
#   Looking for: original_pdbs/1fu2_A_peptide.pdb
#   ✅ TM-score: 0.2808
#
# Processing 223/505: 1fu2_B
#   Generated: PMPNN_Results/1fu2_B.pdb
#   Looking for: original_pdbs/1fu2_B_peptide.pdb
#   ✅ TM-score: 0.3527
#
# Processing 224/505: 1fub_A
#   Generated: PMPNN_Results/1fub_A.pdb
#   Looking for: original_pdbs/1fub_A_peptide.pdb
#   ✅ TM-score: 0.2590
#
# Processing 225/505: 1fub_B
#   Generated: PMPNN_Results/1fub_B.pdb
#   Looking for: original_pdbs/1fub_B_peptide.pdb
#   ✅ TM-score: 0.4671
#
# Processing 226/505: 1fv1_C
#   Generated: PMPNN_Results/1fv1_C.pdb
#   Looking for: original_pdbs/1fv1_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 227/505: 1g0v_B
#   Generated: PMPNN_Results/1g0v_B.pdb
#   Looking for: original_pdbs/1g0v_B_peptide.pdb
#   ✅ TM-score: 0.5528
#
# Processing 228/505: 1g0y_I
#   Generated: PMPNN_Results/1g0y_I.pdb
#   Looking for: original_pdbs/1g0y_I_peptide.pdb
#   ✅ TM-score: 0.3505
#
# Processing 229/505: 1g1i_A
#   Generated: PMPNN_Results/1g1i_A.pdb
#   Looking for: original_pdbs/1g1i_A_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 230/505: 1g1j_A
#   Generated: PMPNN_Results/1g1j_A.pdb
#   Looking for: original_pdbs/1g1j_A_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 231/505: 1g1s_C
#   Generated: PMPNN_Results/1g1s_C.pdb
#   Looking for: original_pdbs/1g1s_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 232/505: 1g2c_B
#   Generated: PMPNN_Results/1g2c_B.pdb
#   Looking for: original_pdbs/1g2c_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 233/505: 1g2y_A
#   Generated: PMPNN_Results/1g2y_A.pdb
#   Looking for: original_pdbs/1g2y_A_peptide.pdb
#   ✅ TM-score: 0.4951
#
# Processing 234/505: 1g2z_A
#   Generated: PMPNN_Results/1g2z_A.pdb
#   Looking for: original_pdbs/1g2z_A_peptide.pdb
#   ✅ TM-score: 0.5347
#
# Processing 235/505: 1g30_A
#   Generated: PMPNN_Results/1g30_A.pdb
#   Looking for: original_pdbs/1g30_A_peptide.pdb
#   ✅ TM-score: 0.2084
#
# Processing 236/505: 1g32_A
#   Generated: PMPNN_Results/1g32_A.pdb
#   Looking for: original_pdbs/1g32_A_peptide.pdb
#   ✅ TM-score: 0.2003
#
# Processing 237/505: 1g39_A
#   Generated: PMPNN_Results/1g39_A.pdb
#   Looking for: original_pdbs/1g39_A_peptide.pdb
#   ✅ TM-score: 0.7277
#
# Processing 238/505: 1g5j_B
#   Generated: PMPNN_Results/1g5j_B.pdb
#   Looking for: original_pdbs/1g5j_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 239/505: 1g6u_A
#   Generated: PMPNN_Results/1g6u_A.pdb
#   Looking for: original_pdbs/1g6u_A_peptide.pdb
#   ✅ TM-score: 0.8823
#
# Processing 240/505: 1g7a_A
#   Generated: PMPNN_Results/1g7a_A.pdb
#   Looking for: original_pdbs/1g7a_A_peptide.pdb
#   ✅ TM-score: 0.3994
#
# Processing 241/505: 1g7a_B
#   Generated: PMPNN_Results/1g7a_B.pdb
#   Looking for: original_pdbs/1g7a_B_peptide.pdb
#   ✅ TM-score: 0.4816
#
# Processing 242/505: 1g7b_A
#   Generated: PMPNN_Results/1g7b_A.pdb
#   Looking for: original_pdbs/1g7b_A_peptide.pdb
#   ✅ TM-score: 0.3539
#
# Processing 243/505: 1g7b_B
#   Generated: PMPNN_Results/1g7b_B.pdb
#   Looking for: original_pdbs/1g7b_B_peptide.pdb
#   ✅ TM-score: 0.4582
#
# Processing 244/505: 1g9i_I
#   Generated: PMPNN_Results/1g9i_I.pdb
#   Looking for: original_pdbs/1g9i_I_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 245/505: 1gcl_A
#   Generated: PMPNN_Results/1gcl_A.pdb
#   Looking for: original_pdbs/1gcl_A_peptide.pdb
#   ✅ TM-score: 0.4899
#
# Processing 246/505: 1gcm_A
#   Generated: PMPNN_Results/1gcm_A.pdb
#   Looking for: original_pdbs/1gcm_A_peptide.pdb
#   ✅ TM-score: 0.4215
#
# Processing 247/505: 1ghv_L
#   Generated: PMPNN_Results/1ghv_L.pdb
#   Looking for: original_pdbs/1ghv_L_peptide.pdb
#   ✅ TM-score: 0.1920
#
# Processing 248/505: 1ghw_L
#   Generated: PMPNN_Results/1ghw_L.pdb
#   Looking for: original_pdbs/1ghw_L_peptide.pdb
#   ✅ TM-score: 0.2002
#
# Processing 249/505: 1ghx_L
#   Generated: PMPNN_Results/1ghx_L.pdb
#   Looking for: original_pdbs/1ghx_L_peptide.pdb
#   ✅ TM-score: 0.1837
#
# Processing 250/505: 1ghy_L
#   Generated: PMPNN_Results/1ghy_L.pdb
#   Looking for: original_pdbs/1ghy_L_peptide.pdb
#   ✅ TM-score: 0.1643
#
# Processing 251/505: 1gi7_A
#   Generated: PMPNN_Results/1gi7_A.pdb
#   Looking for: original_pdbs/1gi7_A_peptide.pdb
#   ✅ TM-score: 0.1111
#
# Processing 252/505: 1gi8_A
#   Generated: PMPNN_Results/1gi8_A.pdb
#   Looking for: original_pdbs/1gi8_A_peptide.pdb
#   ✅ TM-score: 0.1111
#
# Processing 253/505: 1gi9_A
#   Generated: PMPNN_Results/1gi9_A.pdb
#   Looking for: original_pdbs/1gi9_A_peptide.pdb
#   ✅ TM-score: 0.1111
#
# Processing 254/505: 1gj4_L
#   Generated: PMPNN_Results/1gj4_L.pdb
#   Looking for: original_pdbs/1gj4_L_peptide.pdb
#   ✅ TM-score: 0.1623
#
# Processing 255/505: 1gj5_L
#   Generated: PMPNN_Results/1gj5_L.pdb
#   Looking for: original_pdbs/1gj5_L_peptide.pdb
#   ✅ TM-score: 0.1394
#
# Processing 256/505: 1gj7_A
#   Generated: PMPNN_Results/1gj7_A.pdb
#   Looking for: original_pdbs/1gj7_A_peptide.pdb
#   ✅ TM-score: 0.1944
#
# Processing 257/505: 1gj8_A
#   Generated: PMPNN_Results/1gj8_A.pdb
#   Looking for: original_pdbs/1gj8_A_peptide.pdb
#   ✅ TM-score: 0.2425
#
# Processing 258/505: 1gj9_A
#   Generated: PMPNN_Results/1gj9_A.pdb
#   Looking for: original_pdbs/1gj9_A_peptide.pdb
#   ✅ TM-score: 0.1996
#
# Processing 259/505: 1gja_A
#   Generated: PMPNN_Results/1gja_A.pdb
#   Looking for: original_pdbs/1gja_A_peptide.pdb
#   ✅ TM-score: 0.2353
#
# Processing 260/505: 1gjb_A
#   Generated: PMPNN_Results/1gjb_A.pdb
#   Looking for: original_pdbs/1gjb_A_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 261/505: 1gjc_A
#   Generated: PMPNN_Results/1gjc_A.pdb
#   Looking for: original_pdbs/1gjc_A_peptide.pdb
#   ✅ TM-score: 0.1111
#
# Processing 262/505: 1gjd_A
#   Generated: PMPNN_Results/1gjd_A.pdb
#   Looking for: original_pdbs/1gjd_A_peptide.pdb
#   ✅ TM-score: 0.2138
#
# Processing 263/505: 1gl0_I
#   Generated: PMPNN_Results/1gl0_I.pdb
#   Looking for: original_pdbs/1gl0_I_peptide.pdb
#   ✅ TM-score: 0.2479
#
# Processing 264/505: 1gl1_I
#   Generated: PMPNN_Results/1gl1_I.pdb
#   Looking for: original_pdbs/1gl1_I_peptide.pdb
#   ✅ TM-score: 0.2222
#
# Processing 265/505: 1gng_X
#   Generated: PMPNN_Results/1gng_X.pdb
#   Looking for: original_pdbs/1gng_X_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 266/505: 1guj_A
#   Generated: PMPNN_Results/1guj_A.pdb
#   Looking for: original_pdbs/1guj_A_peptide.pdb
#   ✅ TM-score: 0.3640
#
# Processing 267/505: 1guj_B
#   Generated: PMPNN_Results/1guj_B.pdb
#   Looking for: original_pdbs/1guj_B_peptide.pdb
#   ✅ TM-score: 0.3979
#
# Processing 268/505: 1gzl_A
#   Generated: PMPNN_Results/1gzl_A.pdb
#   Looking for: original_pdbs/1gzl_A_peptide.pdb
#   ✅ TM-score: 0.3802
#
# Processing 269/505: 1h2k_S
#   Generated: PMPNN_Results/1h2k_S.pdb
#   Looking for: original_pdbs/1h2k_S_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 270/505: 1h2l_S
#   Generated: PMPNN_Results/1h2l_S.pdb
#   Looking for: original_pdbs/1h2l_S_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 271/505: 1h8d_L
#   Generated: PMPNN_Results/1h8d_L.pdb
#   Looking for: original_pdbs/1h8d_L_peptide.pdb
#   ✅ TM-score: 0.1786
#
# Processing 272/505: 1h8i_L
#   Generated: PMPNN_Results/1h8i_L.pdb
#   Looking for: original_pdbs/1h8i_L_peptide.pdb
#   ✅ TM-score: 0.1974
#
# Processing 273/505: 1h9h_I
#   Generated: PMPNN_Results/1h9h_I.pdb
#   Looking for: original_pdbs/1h9h_I_peptide.pdb
#   ✅ TM-score: 0.8590
#
# Processing 274/505: 1h9i_I
#   Generated: PMPNN_Results/1h9i_I.pdb
#   Looking for: original_pdbs/1h9i_I_peptide.pdb
#   ✅ TM-score: 0.8532
#
# Processing 275/505: 1hah_L
#   Generated: PMPNN_Results/1hah_L.pdb
#   Looking for: original_pdbs/1hah_L_peptide.pdb
#   ✅ TM-score: 0.1322
#
# Processing 276/505: 1hai_L
#   Generated: PMPNN_Results/1hai_L.pdb
#   Looking for: original_pdbs/1hai_L_peptide.pdb
#   ✅ TM-score: 0.1718
#
# Processing 277/505: 1hbt_L
#   Generated: PMPNN_Results/1hbt_L.pdb
#   Looking for: original_pdbs/1hbt_L_peptide.pdb
#   ✅ TM-score: 0.2126
#
# Processing 278/505: 1hdt_L
#   Generated: PMPNN_Results/1hdt_L.pdb
#   Looking for: original_pdbs/1hdt_L_peptide.pdb
#   ✅ TM-score: 0.1791
#
# Processing 279/505: 1hf9_A
#   Generated: PMPNN_Results/1hf9_A.pdb
#   Looking for: original_pdbs/1hf9_A_peptide.pdb
#   ✅ TM-score: 0.4116
#
# Processing 280/505: 1hgt_L
#   Generated: PMPNN_Results/1hgt_L.pdb
#   Looking for: original_pdbs/1hgt_L_peptide.pdb
#   ✅ TM-score: 0.2081
#
# Processing 281/505: 1hia_I
#   Generated: PMPNN_Results/1hia_I.pdb
#   Looking for: original_pdbs/1hia_I_peptide.pdb
#   ✅ TM-score: 0.1772
#
# Processing 282/505: 1hiq_A
#   Generated: PMPNN_Results/1hiq_A.pdb
#   Looking for: original_pdbs/1hiq_A_peptide.pdb
#   ✅ TM-score: 0.2739
#
# Processing 283/505: 1hiq_B
#   Generated: PMPNN_Results/1hiq_B.pdb
#   Looking for: original_pdbs/1hiq_B_peptide.pdb
#   ✅ TM-score: 0.3981
#
# Processing 284/505: 1his_A
#   Generated: PMPNN_Results/1his_A.pdb
#   Looking for: original_pdbs/1his_A_peptide.pdb
#   ✅ TM-score: 0.2474
#
# Processing 285/505: 1his_B
#   Generated: PMPNN_Results/1his_B.pdb
#   Looking for: original_pdbs/1his_B_peptide.pdb
#   ✅ TM-score: 0.3491
#
# Processing 286/505: 1hit_A
#   Generated: PMPNN_Results/1hit_A.pdb
#   Looking for: original_pdbs/1hit_A_peptide.pdb
#   ✅ TM-score: 0.2100
#
# Processing 287/505: 1hit_B
#   Generated: PMPNN_Results/1hit_B.pdb
#   Looking for: original_pdbs/1hit_B_peptide.pdb
#   ✅ TM-score: 0.4194
#
# Processing 288/505: 1hle_B
#   Generated: PMPNN_Results/1hle_B.pdb
#   Looking for: original_pdbs/1hle_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 289/505: 1hls_A
#   Generated: PMPNN_Results/1hls_A.pdb
#   Looking for: original_pdbs/1hls_A_peptide.pdb
#   ✅ TM-score: 0.2340
#
# Processing 290/505: 1hls_B
#   Generated: PMPNN_Results/1hls_B.pdb
#   Looking for: original_pdbs/1hls_B_peptide.pdb
#   ✅ TM-score: 0.3782
#
# Processing 291/505: 1hlt_L
#   Generated: PMPNN_Results/1hlt_L.pdb
#   Looking for: original_pdbs/1hlt_L_peptide.pdb
#   ✅ TM-score: 0.2012
#
# Processing 292/505: 1hr8_O
#   Generated: PMPNN_Results/1hr8_O.pdb
#   Looking for: original_pdbs/1hr8_O_peptide.pdb
#   ✅ TM-score: 0.1807
#
# Processing 293/505: 1hrt_L
#   Generated: PMPNN_Results/1hrt_L.pdb
#   Looking for: original_pdbs/1hrt_L_peptide.pdb
#   ✅ TM-score: 0.1431
#
# Processing 294/505: 1hs5_A
#   Generated: PMPNN_Results/1hs5_A.pdb
#   Looking for: original_pdbs/1hs5_A_peptide.pdb
#   ✅ TM-score: 0.4557
#
# Processing 295/505: 1htl_C
#   Generated: PMPNN_Results/1htl_C.pdb
#   Looking for: original_pdbs/1htl_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 296/505: 1htm_A
#   Generated: PMPNN_Results/1htm_A.pdb
#   Looking for: original_pdbs/1htm_A_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 297/505: 1htr_P
#   Generated: PMPNN_Results/1htr_P.pdb
#   Looking for: original_pdbs/1htr_P_peptide.pdb
#   ✅ TM-score: 0.2847
#
# Processing 298/505: 1htv_A
#   Generated: PMPNN_Results/1htv_A.pdb
#   Looking for: original_pdbs/1htv_A_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 299/505: 1htv_B
#   Generated: PMPNN_Results/1htv_B.pdb
#   Looking for: original_pdbs/1htv_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 300/505: 1huc_A
#   Generated: PMPNN_Results/1huc_A.pdb
#   Looking for: original_pdbs/1huc_A_peptide.pdb
#   ✅ TM-score: 0.4860
#
# Processing 301/505: 1hui_A
#   Generated: PMPNN_Results/1hui_A.pdb
#   Looking for: original_pdbs/1hui_A_peptide.pdb
#   ✅ TM-score: 0.2336
#
# Processing 302/505: 1hui_B
#   Generated: PMPNN_Results/1hui_B.pdb
#   Looking for: original_pdbs/1hui_B_peptide.pdb
#   ✅ TM-score: 0.3989
#
# Processing 303/505: 1hxe_L
#   Generated: PMPNN_Results/1hxe_L.pdb
#   Looking for: original_pdbs/1hxe_L_peptide.pdb
#   ✅ TM-score: 0.1428
#
# Processing 304/505: 1hxf_L
#   Generated: PMPNN_Results/1hxf_L.pdb
#   Looking for: original_pdbs/1hxf_L_peptide.pdb
#   ✅ TM-score: 0.1803
#
# Processing 305/505: 1hym_A
#   Generated: PMPNN_Results/1hym_A.pdb
#   Looking for: original_pdbs/1hym_A_peptide.pdb
#   ✅ TM-score: 0.5442
#
# Processing 306/505: 1hym_B
#   Generated: PMPNN_Results/1hym_B.pdb
#   Looking for: original_pdbs/1hym_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 307/505: 1i5k_C
#   Generated: PMPNN_Results/1i5k_C.pdb
#   Looking for: original_pdbs/1i5k_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 308/505: 1i8g_B
#   Generated: PMPNN_Results/1i8g_B.pdb
#   Looking for: original_pdbs/1i8g_B_peptide.pdb
#   ✅ TM-score: 0.5595
#
# Processing 309/505: 1i8h_B
#   Generated: PMPNN_Results/1i8h_B.pdb
#   Looking for: original_pdbs/1i8h_B_peptide.pdb
#   ✅ TM-score: 0.4437
#
# Processing 310/505: 1icf_B
#   Generated: PMPNN_Results/1icf_B.pdb
#   Looking for: original_pdbs/1icf_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 311/505: 1id5_L
#   Generated: PMPNN_Results/1id5_L.pdb
#   Looking for: original_pdbs/1id5_L_peptide.pdb
#   ✅ TM-score: 0.1695
#
# Processing 312/505: 1ihq_A
#   Generated: PMPNN_Results/1ihq_A.pdb
#   Looking for: original_pdbs/1ihq_A_peptide.pdb
#   ✅ TM-score: 0.3589
#
# Processing 313/505: 1ihs_I
#   Generated: PMPNN_Results/1ihs_I.pdb
#   Looking for: original_pdbs/1ihs_I_peptide.pdb
#   ✅ TM-score: 0.0588
#
# Processing 314/505: 1ihs_L
#   Generated: PMPNN_Results/1ihs_L.pdb
#   Looking for: original_pdbs/1ihs_L_peptide.pdb
#   ✅ TM-score: 0.1770
#
# Processing 315/505: 1iht_L
#   Generated: PMPNN_Results/1iht_L.pdb
#   Looking for: original_pdbs/1iht_L_peptide.pdb
#   ✅ TM-score: 0.1656
#
# Processing 316/505: 1ij0_A
#   Generated: PMPNN_Results/1ij0_A.pdb
#   Looking for: original_pdbs/1ij0_A_peptide.pdb
#   ✅ TM-score: 0.4810
#
# Processing 317/505: 1ij1_A
#   Generated: PMPNN_Results/1ij1_A.pdb
#   Looking for: original_pdbs/1ij1_A_peptide.pdb
#   ✅ TM-score: 0.8282
#
# Processing 318/505: 1ij2_A
#   Generated: PMPNN_Results/1ij2_A.pdb
#   Looking for: original_pdbs/1ij2_A_peptide.pdb
#   ✅ TM-score: 0.3841
#
# Processing 319/505: 1ij3_A
#   Generated: PMPNN_Results/1ij3_A.pdb
#   Looking for: original_pdbs/1ij3_A_peptide.pdb
#   ✅ TM-score: 0.6572
#
# Processing 320/505: 1ijd_B
#   Generated: PMPNN_Results/1ijd_B.pdb
#   Looking for: original_pdbs/1ijd_B_peptide.pdb
#   ✅ TM-score: 0.4728
#
# Processing 321/505: 1ik9_C
#   Generated: PMPNN_Results/1ik9_C.pdb
#   Looking for: original_pdbs/1ik9_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 322/505: 1iod_G
#   Generated: PMPNN_Results/1iod_G.pdb
#   Looking for: original_pdbs/1iod_G_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 323/505: 1iog_A
#   Generated: PMPNN_Results/1iog_A.pdb
#   Looking for: original_pdbs/1iog_A_peptide.pdb
#   ✅ TM-score: 0.2504
#
# Processing 324/505: 1iog_B
#   Generated: PMPNN_Results/1iog_B.pdb
#   Looking for: original_pdbs/1iog_B_peptide.pdb
#   ✅ TM-score: 0.2727
#
# Processing 325/505: 1ioh_A
#   Generated: PMPNN_Results/1ioh_A.pdb
#   Looking for: original_pdbs/1ioh_A_peptide.pdb
#   ✅ TM-score: 0.2630
#
# Processing 326/505: 1ioh_B
#   Generated: PMPNN_Results/1ioh_B.pdb
#   Looking for: original_pdbs/1ioh_B_peptide.pdb
#   ✅ TM-score: 0.4562
#
# Processing 327/505: 1iq5_B
#   Generated: PMPNN_Results/1iq5_B.pdb
#   Looking for: original_pdbs/1iq5_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 328/505: 1iza_A
#   Generated: PMPNN_Results/1iza_A.pdb
#   Looking for: original_pdbs/1iza_A_peptide.pdb
#   ✅ TM-score: 0.2871
#
# Processing 329/505: 1iza_B
#   Generated: PMPNN_Results/1iza_B.pdb
#   Looking for: original_pdbs/1iza_B_peptide.pdb
#   ✅ TM-score: 0.5285
#
# Processing 330/505: 1izb_A
#   Generated: PMPNN_Results/1izb_A.pdb
#   Looking for: original_pdbs/1izb_A_peptide.pdb
#   ✅ TM-score: 0.2824
#
# Processing 331/505: 1izb_B
#   Generated: PMPNN_Results/1izb_B.pdb
#   Looking for: original_pdbs/1izb_B_peptide.pdb
#   ✅ TM-score: 0.4847
#
# Processing 332/505: 1izl_F
#   Generated: PMPNN_Results/1izl_F.pdb
#   Looking for: original_pdbs/1izl_F_peptide.pdb
#   ✅ TM-score: 0.1552
#
# Processing 333/505: 1izl_K
#   Generated: PMPNN_Results/1izl_K.pdb
# ...
#   Looking for: original_pdbs/1krl_A_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 399/505: 1kts_A
#   Generated: PMPNN_Results/1kts_A.pdb
#   Looking for: original_pdbs/1kts_A_peptide.pdb
#   ✅ TM-score: 0.1450
#
# Processing 400/505: 1ktt_A
#   Generated: PMPNN_Results/1ktt_A.pdb
#   Looking for: original_pdbs/1ktt_A_peptide.pdb
#   ✅ TM-score: 0.1941
#
# Processing 401/505: 1kup_B
#   Generated: PMPNN_Results/1kup_B.pdb
#   Looking for: original_pdbs/1kup_B_peptide.pdb
#   ✅ TM-score: 0.2054
#
# Processing 402/505: 1kuz_B
#   Generated: PMPNN_Results/1kuz_B.pdb
#   Looking for: original_pdbs/1kuz_B_peptide.pdb
#   ✅ TM-score: 0.2857
#
# Processing 403/505: 1kzu_B
#   Generated: PMPNN_Results/1kzu_B.pdb
#   Looking for: original_pdbs/1kzu_B_peptide.pdb
#   ✅ TM-score: 0.6822
#
# Processing 404/505: 1l3e_A
#   Generated: PMPNN_Results/1l3e_A.pdb
#   Looking for: original_pdbs/1l3e_A_peptide.pdb
#   ✅ TM-score: 0.2838
#
# Processing 405/505: 1l3r_I
#   Generated: PMPNN_Results/1l3r_I.pdb
#   Looking for: original_pdbs/1l3r_I_peptide.pdb
#   ✅ TM-score: 0.2690
#
# Processing 406/505: 1l4w_B
#   Generated: PMPNN_Results/1l4w_B.pdb
#   Looking for: original_pdbs/1l4w_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 407/505: 1l6e_A
#   Generated: PMPNN_Results/1l6e_A.pdb
#   Looking for: original_pdbs/1l6e_A_peptide.pdb
#   ✅ TM-score: 0.4056
#
# Processing 408/505: 1l6x_B
#   Generated: PMPNN_Results/1l6x_B.pdb
#   Looking for: original_pdbs/1l6x_B_peptide.pdb
#   ✅ TM-score: 0.3159
#
# Processing 409/505: 1ldk_E
#   Generated: PMPNN_Results/1ldk_E.pdb
#   Looking for: original_pdbs/1ldk_E_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 410/505: 1ldt_L
#   Generated: PMPNN_Results/1ldt_L.pdb
#   Looking for: original_pdbs/1ldt_L_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 411/505: 1lgh_B
#   Generated: PMPNN_Results/1lgh_B.pdb
#   Looking for: original_pdbs/1lgh_B_peptide.pdb
#   ✅ TM-score: 0.3633
#
# Processing 412/505: 1lhc_L
#   Generated: PMPNN_Results/1lhc_L.pdb
#   Looking for: original_pdbs/1lhc_L_peptide.pdb
#   ✅ TM-score: 0.1501
#
# Processing 413/505: 1lhd_L
#   Generated: PMPNN_Results/1lhd_L.pdb
#   Looking for: original_pdbs/1lhd_L_peptide.pdb
#   ✅ TM-score: 0.1765
#
# Processing 414/505: 1lhe_L
#   Generated: PMPNN_Results/1lhe_L.pdb
#   Looking for: original_pdbs/1lhe_L_peptide.pdb
#   ✅ TM-score: 0.2299
#
# Processing 415/505: 1lhf_L
#   Generated: PMPNN_Results/1lhf_L.pdb
#   Looking for: original_pdbs/1lhf_L_peptide.pdb
#   ✅ TM-score: 0.1985
#
# Processing 416/505: 1lhg_L
#   Generated: PMPNN_Results/1lhg_L.pdb
#   Looking for: original_pdbs/1lhg_L_peptide.pdb
#   ✅ TM-score: 0.2166
#
# Processing 417/505: 1lj2_C
#   Generated: PMPNN_Results/1lj2_C.pdb
#   Looking for: original_pdbs/1lj2_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 418/505: 1ljz_B
#   Generated: PMPNN_Results/1ljz_B.pdb
#   Looking for: original_pdbs/1ljz_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 419/505: 1lkq_A
#   Generated: PMPNN_Results/1lkq_A.pdb
#   Looking for: original_pdbs/1lkq_A_peptide.pdb
#   ✅ TM-score: 0.2718
#
# Processing 420/505: 1lkq_B
#   Generated: PMPNN_Results/1lkq_B.pdb
#   Looking for: original_pdbs/1lkq_B_peptide.pdb
#   ✅ TM-score: 0.4155
#
# Processing 421/505: 1lm8_H
#   Generated: PMPNN_Results/1lm8_H.pdb
#   Looking for: original_pdbs/1lm8_H_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 422/505: 1lmw_A
#   Generated: PMPNN_Results/1lmw_A.pdb
#   Looking for: original_pdbs/1lmw_A_peptide.pdb
#   ✅ TM-score: 0.2982
#
# Processing 423/505: 1lph_A
#   Generated: PMPNN_Results/1lph_A.pdb
#   Looking for: original_pdbs/1lph_A_peptide.pdb
#   ✅ TM-score: 0.3367
#
# Processing 424/505: 1lph_B
#   Generated: PMPNN_Results/1lph_B.pdb
#   Looking for: original_pdbs/1lph_B_peptide.pdb
#   ✅ TM-score: 0.5034
#
# Processing 425/505: 1lq8_B
#   Generated: PMPNN_Results/1lq8_B.pdb
#   Looking for: original_pdbs/1lq8_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 426/505: 1lqb_D
#   Generated: PMPNN_Results/1lqb_D.pdb
#   Looking for: original_pdbs/1lqb_D_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 427/505: 1lqv_C
#   Generated: PMPNN_Results/1lqv_C.pdb
#   Looking for: original_pdbs/1lqv_C_peptide.pdb
#   ✅ TM-score: 0.0899
#
# Processing 428/505: 1lta_C
#   Generated: PMPNN_Results/1lta_C.pdb
#   Looking for: original_pdbs/1lta_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 429/505: 1ltb_C
#   Generated: PMPNN_Results/1ltb_C.pdb
#   Looking for: original_pdbs/1ltb_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 430/505: 1ltg_C
#   Generated: PMPNN_Results/1ltg_C.pdb
#   Looking for: original_pdbs/1ltg_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 431/505: 1lti_C
#   Generated: PMPNN_Results/1lti_C.pdb
#   Looking for: original_pdbs/1lti_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 432/505: 1lts_C
#   Generated: PMPNN_Results/1lts_C.pdb
#   Looking for: original_pdbs/1lts_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 433/505: 1ltt_C
#   Generated: PMPNN_Results/1ltt_C.pdb
#   Looking for: original_pdbs/1ltt_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 434/505: 1lu0_A
#   Generated: PMPNN_Results/1lu0_A.pdb
#   Looking for: original_pdbs/1lu0_A_peptide.pdb
#   ✅ TM-score: 0.8281
#
# Processing 435/505: 1m1d_B
#   Generated: PMPNN_Results/1m1d_B.pdb
#   Looking for: original_pdbs/1m1d_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 436/505: 1m2z_B
#   Generated: PMPNN_Results/1m2z_B.pdb
#   Looking for: original_pdbs/1m2z_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 437/505: 1m3w_A
#   Generated: PMPNN_Results/1m3w_A.pdb
#   Looking for: original_pdbs/1m3w_A_peptide.pdb
#   ✅ TM-score: 0.4222
#
# Processing 438/505: 1m45_B
#   Generated: PMPNN_Results/1m45_B.pdb
#   Looking for: original_pdbs/1m45_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 439/505: 1m46_B
#   Generated: PMPNN_Results/1m46_B.pdb
#   Looking for: original_pdbs/1m46_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 440/505: 1m5a_A
#   Generated: PMPNN_Results/1m5a_A.pdb
#   Looking for: original_pdbs/1m5a_A_peptide.pdb
#   ✅ TM-score: 0.2957
#
# Processing 441/505: 1m5a_B
#   Generated: PMPNN_Results/1m5a_B.pdb
#   Looking for: original_pdbs/1m5a_B_peptide.pdb
#   ✅ TM-score: 0.5127
#
# Processing 442/505: 1m5n_Q
#   Generated: PMPNN_Results/1m5n_Q.pdb
#   Looking for: original_pdbs/1m5n_Q_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 443/505: 1m7l_A
#   Generated: PMPNN_Results/1m7l_A.pdb
#   Looking for: original_pdbs/1m7l_A_peptide.pdb
#   ✅ TM-score: 0.2767
#
# Processing 444/505: 1m8o_A
#   Generated: PMPNN_Results/1m8o_A.pdb
#   Looking for: original_pdbs/1m8o_A_peptide.pdb
#   ✅ TM-score: 0.2150
#
# Processing 445/505: 1m8o_B
#   Generated: PMPNN_Results/1m8o_B.pdb
#   Looking for: original_pdbs/1m8o_B_peptide.pdb
#   ✅ TM-score: 0.2912
#
# Processing 446/505: 1m93_C
#   Generated: PMPNN_Results/1m93_C.pdb
#   Looking for: original_pdbs/1m93_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 447/505: 1mct_I
#   Generated: PMPNN_Results/1mct_I.pdb
#   Looking for: original_pdbs/1mct_I_peptide.pdb
#   ✅ TM-score: 0.8396
#
# Processing 448/505: 1mcv_I
#   Generated: PMPNN_Results/1mcv_I.pdb
#   Looking for: original_pdbs/1mcv_I_peptide.pdb
#   ✅ TM-score: 0.7493
#
# Processing 449/505: 1mhi_A
#   Generated: PMPNN_Results/1mhi_A.pdb
#   Looking for: original_pdbs/1mhi_A_peptide.pdb
#   ✅ TM-score: 0.1896
#
# Processing 450/505: 1mhi_B
#   Generated: PMPNN_Results/1mhi_B.pdb
#   Looking for: original_pdbs/1mhi_B_peptide.pdb
#   ✅ TM-score: 0.3993
#
# Processing 451/505: 1mhj_A
#   Generated: PMPNN_Results/1mhj_A.pdb
#   Looking for: original_pdbs/1mhj_A_peptide.pdb
#   ✅ TM-score: 0.3183
#
# Processing 452/505: 1mhj_B
#   Generated: PMPNN_Results/1mhj_B.pdb
#   Looking for: original_pdbs/1mhj_B_peptide.pdb
#   ✅ TM-score: 0.3571
#
# Processing 453/505: 1mhw_C
#   Generated: PMPNN_Results/1mhw_C.pdb
#   Looking for: original_pdbs/1mhw_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 454/505: 1mk2_B
#   Generated: PMPNN_Results/1mk2_B.pdb
#   Looking for: original_pdbs/1mk2_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 455/505: 1mkw_L
#   Generated: PMPNN_Results/1mkw_L.pdb
#   Looking for: original_pdbs/1mkw_L_peptide.pdb
#   ✅ TM-score: 0.1973
#
# Processing 456/505: 1mkx_L
#   Generated: PMPNN_Results/1mkx_L.pdb
#   Looking for: original_pdbs/1mkx_L_peptide.pdb
#   ✅ TM-score: 0.1586
#
# Processing 457/505: 1mpj_A
#   Generated: PMPNN_Results/1mpj_A.pdb
#   Looking for: original_pdbs/1mpj_A_peptide.pdb
#   ✅ TM-score: 0.4195
#
# Processing 458/505: 1mpj_B
#   Generated: PMPNN_Results/1mpj_B.pdb
#   Looking for: original_pdbs/1mpj_B_peptide.pdb
#   ✅ TM-score: 0.4746
#
# Processing 459/505: 1mso_A
#   Generated: PMPNN_Results/1mso_A.pdb
#   Looking for: original_pdbs/1mso_A_peptide.pdb
#   ✅ TM-score: 0.2860
#
# Processing 460/505: 1mso_B
#   Generated: PMPNN_Results/1mso_B.pdb
#   Looking for: original_pdbs/1mso_B_peptide.pdb
#   ✅ TM-score: 0.5015
#
# Processing 461/505: 1mtp_B
#   Generated: PMPNN_Results/1mtp_B.pdb
#   Looking for: original_pdbs/1mtp_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 462/505: 1mu6_A
#   Generated: PMPNN_Results/1mu6_A.pdb
#   Looking for: original_pdbs/1mu6_A_peptide.pdb
#   ✅ TM-score: 0.1830
#
# Processing 463/505: 1mu8_A
#   Generated: PMPNN_Results/1mu8_A.pdb
#   Looking for: original_pdbs/1mu8_A_peptide.pdb
#   ✅ TM-score: 0.1893
#
# Processing 464/505: 1mue_A
#   Generated: PMPNN_Results/1mue_A.pdb
#   Looking for: original_pdbs/1mue_A_peptide.pdb
#   ✅ TM-score: 0.1718
#
# Processing 465/505: 1muj_C
#   Generated: PMPNN_Results/1muj_C.pdb
#   Looking for: original_pdbs/1muj_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 466/505: 1mv4_A
#   Generated: PMPNN_Results/1mv4_A.pdb
#   Looking for: original_pdbs/1mv4_A_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 467/505: 1mxe_E
#   Generated: PMPNN_Results/1mxe_E.pdb
#   Looking for: original_pdbs/1mxe_E_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 468/505: 1mz9_A
#   Generated: PMPNN_Results/1mz9_A.pdb
#   Looking for: original_pdbs/1mz9_A_peptide.pdb
#   ✅ TM-score: 0.3179
#
# Processing 469/505: 1mzw_B
#   Generated: PMPNN_Results/1mzw_B.pdb
#   Looking for: original_pdbs/1mzw_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 470/505: 1n0w_B
#   Generated: PMPNN_Results/1n0w_B.pdb
#   Looking for: original_pdbs/1n0w_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 471/505: 1n0x_P
#   Generated: PMPNN_Results/1n0x_P.pdb
#   Looking for: original_pdbs/1n0x_P_peptide.pdb
#   ✅ TM-score: 0.1617
#
# Processing 472/505: 1n1l_C
#   Generated: PMPNN_Results/1n1l_C.pdb
#   Looking for: original_pdbs/1n1l_C_peptide.pdb
#   ✅ TM-score: 0.0945
#
# Processing 473/505: 1n2d_C
#   Generated: PMPNN_Results/1n2d_C.pdb
#   Looking for: original_pdbs/1n2d_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 474/505: 1ni8_A
#   Generated: PMPNN_Results/1ni8_A.pdb
#   Looking for: original_pdbs/1ni8_A_peptide.pdb
#   ✅ TM-score: 0.6501
#
# Processing 475/505: 1niw_B
#   Generated: PMPNN_Results/1niw_B.pdb
#   Looking for: original_pdbs/1niw_B_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 476/505: 1nkz_B
#   Generated: PMPNN_Results/1nkz_B.pdb
#   Looking for: original_pdbs/1nkz_B_peptide.pdb
#   ✅ TM-score: 0.4337
#
# Processing 477/505: 1no9_L
#   Generated: PMPNN_Results/1no9_L.pdb
#   Looking for: original_pdbs/1no9_L_peptide.pdb
#   ✅ TM-score: 0.1878
#
# Processing 478/505: 1nov_D
#   Generated: PMPNN_Results/1nov_D.pdb
#   Looking for: original_pdbs/1nov_D_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 479/505: 1nrl_C
#   Generated: PMPNN_Results/1nrl_C.pdb
#   Looking for: original_pdbs/1nrl_C_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 480/505: 1nrn_L
#   Generated: PMPNN_Results/1nrn_L.pdb
#   Looking for: original_pdbs/1nrn_L_peptide.pdb
#   ✅ TM-score: 0.1900
#
# Processing 481/505: 1nrn_R
#   Generated: PMPNN_Results/1nrn_R.pdb
#   Looking for: original_pdbs/1nrn_R_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 482/505: 1nro_L
#   Generated: PMPNN_Results/1nro_L.pdb
#   Looking for: original_pdbs/1nro_L_peptide.pdb
#   ✅ TM-score: 0.2085
#
# Processing 483/505: 1nro_R
#   Generated: PMPNN_Results/1nro_R.pdb
#   Looking for: original_pdbs/1nro_R_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 484/505: 1nrp_L
#   Generated: PMPNN_Results/1nrp_L.pdb
#   Looking for: original_pdbs/1nrp_L_peptide.pdb
#   ✅ TM-score: 0.2014
#
# Processing 485/505: 1nrp_R
#   Generated: PMPNN_Results/1nrp_R.pdb
#   Looking for: original_pdbs/1nrp_R_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 486/505: 1nrq_L
#   Generated: PMPNN_Results/1nrq_L.pdb
#   Looking for: original_pdbs/1nrq_L_peptide.pdb
#   ✅ TM-score: 0.2141
#
# Processing 487/505: 1nrq_R
#   Generated: PMPNN_Results/1nrq_R.pdb
#   Looking for: original_pdbs/1nrq_R_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 488/505: 1nrr_L
#   Generated: PMPNN_Results/1nrr_L.pdb
#   Looking for: original_pdbs/1nrr_L_peptide.pdb
#   ✅ TM-score: 0.2202
#
# Processing 489/505: 1nrs_L
#   Generated: PMPNN_Results/1nrs_L.pdb
#   Looking for: original_pdbs/1nrs_L_peptide.pdb
#   ✅ TM-score: 0.2127
#
# Processing 490/505: 1nu7_A
#   Generated: PMPNN_Results/1nu7_A.pdb
#   Looking for: original_pdbs/1nu7_A_peptide.pdb
#   ✅ TM-score: 0.2082
#
# Processing 491/505: 1nwd_B
#   Generated: PMPNN_Results/1nwd_B.pdb
#   Looking for: original_pdbs/1nwd_B_peptide.pdb
#   ✅ TM-score: 0.5927
#
# Processing 492/505: 1nyj_A
#   Generated: PMPNN_Results/1nyj_A.pdb
#   Looking for: original_pdbs/1nyj_A_peptide.pdb
#   ✅ TM-score: 0.8863
#
# Processing 493/505: 1nzq_L
#   Generated: PMPNN_Results/1nzq_L.pdb
#   Looking for: original_pdbs/1nzq_L_peptide.pdb
#   ✅ TM-score: 0.2134
#
# Processing 494/505: 1o0d_L
#   Generated: PMPNN_Results/1o0d_L.pdb
#   Looking for: original_pdbs/1o0d_L_peptide.pdb
#   ✅ TM-score: 0.1520
#
# Processing 495/505: 1o2g_L
#   Generated: PMPNN_Results/1o2g_L.pdb
#   Looking for: original_pdbs/1o2g_L_peptide.pdb
#   ✅ TM-score: 0.1887
#
# Processing 496/505: 1o3p_A
#   Generated: PMPNN_Results/1o3p_A.pdb
#   Looking for: original_pdbs/1o3p_A_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 497/505: 1o5a_A
#   Generated: PMPNN_Results/1o5a_A.pdb
#   Looking for: original_pdbs/1o5a_A_peptide.pdb
#   ✅ TM-score: 0.1111
#
# Processing 498/505: 1o5b_A
#   Generated: PMPNN_Results/1o5b_A.pdb
#   Looking for: original_pdbs/1o5b_A_peptide.pdb
#   ⚠️  No common residues found between structures
#
# Processing 499/505: 1o5c_A
#   Generated: PMPNN_Results/1o5c_A.pdb
#   Looking for: original_pdbs/1o5c_A_peptide.pdb
#   ✅ TM-score: 0.1111
#
# Processing 500/505: 1o5g_L
#   Generated: PMPNN_Results/1o5g_L.pdb
#   Looking for: original_pdbs/1o5g_L_peptide.pdb
#   ✅ TM-score: 0.1749
#
# Processing 501/505: 1o9a_B
#   Generated: PMPNN_Results/1o9a_B.pdb
#   Looking for: original_pdbs/1o9a_B_peptide.pdb
#   ✅ TM-score: 0.1358
#
# Processing 502/505: 1occ_L
#   Generated: PMPNN_Results/1occ_L.pdb
#   Looking for: original_pdbs/1occ_L_peptide.pdb
#   ✅ TM-score: 0.3621
#
# Processing 503/505: 1occ_M
#   Generated: PMPNN_Results/1occ_M.pdb
#   Looking for: original_pdbs/1occ_M_peptide.pdb
#   ✅ TM-score: 0.4326
#
# Processing 504/505: 1oco_L
#   Generated: PMPNN_Results/1oco_L.pdb
#   Looking for: original_pdbs/1oco_L_peptide.pdb
#   ✅ TM-score: 0.3647
#
# Processing 505/505: 1oco_M
#   Generated: PMPNN_Results/1oco_M.pdb
#   Looking for: original_pdbs/1oco_M_peptide.pdb
#   ✅ TM-score: 0.3883
#
# ==================================================
# COMPARISON COMPLETE!
# ==================================================
# Total comparisons: 505
# Successful: 388
# Failed: 117
# Success rate: 76.8%
#
# TM-Score Statistics:
# Average: 0.3182
# Median: 0.2621
# Best: 0.9505
# Worst: 0.0495
# Std Dev: 0.1862
#
# 📄 Results saved to: PMPNN_TMscore.csv

# %%
# Display top results
if results is not None:
    print("\n🏆 TOP 10 RESULTS BY TM-SCORE:")
    print("=" * 60)
    
    top_results = results[results['status'] == 'success'].head(10)
    
    for i, (_, row) in enumerate(top_results.iterrows(), 1):
        print(f"{i:2d}. {row['pdb_id']:20s} | TM-score: {row['tm_score']:.4f}")
else:
    print("No results to display")

# %%
# Optional: Create a summary report
if results is not None:
    # Create summary by status
    status_summary = results['status'].value_counts()
    
    print("\n📊 SUMMARY BY STATUS:")
    print("=" * 30)
    for status, count in status_summary.items():
        print(f"{status:20s}: {count:3d}")
    
    # Save summary
    summary_file = OUTPUT_CSV.replace('.csv', '_summary.txt')
    with open(summary_file, 'w') as f:
        f.write(f"TM-Score Comparison Summary\n")
        f.write(f"Generated at: {datetime.now()}\n")
        f.write(f"="*50 + "\n")
        f.write(f"Generated folder: {GENERATED_PDB_FOLDER}\n")
        f.write(f"Original folder: {ORIGINAL_PDB_FOLDER}\n")
        f.write(f"Total comparisons: {len(results)}\n")
        f.write(f"\nStatus Summary:\n")
        for status, count in status_summary.items():
            f.write(f"{status}: {count}\n")
        
        successful_results = results[results['status'] == 'success']
        if len(successful_results) > 0:
            f.write(f"\nTM-Score Statistics:\n")
            f.write(f"Average: {successful_results['tm_score'].mean():.4f}\n")
            f.write(f"Median: {successful_results['tm_score'].median():.4f}\n")
            f.write(f"Best: {successful_results['tm_score'].max():.4f}\n")
            f.write(f"Worst: {successful_results['tm_score'].min():.4f}\n")
            f.write(f"Std Dev: {successful_results['tm_score'].std():.4f}\n")
    
    print(f"\n📄 Summary saved to: {summary_file}")
else:
    print("No summary to create")
